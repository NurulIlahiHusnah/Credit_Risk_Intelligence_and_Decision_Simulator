# %%
# Mengimport library yang aka digunakan
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#pd.set_option('display.max_rows',None)  # Mengatur jumlah maksimal baris yang ditampilkan
#pd.set_option('display.max_columns',None)  # Menampilkan semua kolom (tanpa batasan)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Mengimport library yang aka digunakan
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Mengupload data
data = pd.read_csv(r"C:\Users\USER\Documents\Mini Project (Portofolio)\VIX Idx Partner\loan_data_2007_2014.csv",index_col=0)
data.info()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12584\3927323206.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\USER\Documents\Mini Project (Portofolio)\VIX Idx Partner\loan_data_2007_2014.csv",index_col=0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438697 non-null  object
#  11  emp_length                   445277 non-null  object
#  12  home_ownership               466285 non-null  object
#  13  annual_inc                   466281 non-null  float64
#  14  verification_status          466285 non-null  object
#  15  issue_d                      466285 non-null  object
#  16  loan_status                  466285 non-null  object
#  17  pymnt_plan                   466285 non-null  object
#  18  url                          466285 non-null  object
#  19  desc                         125981 non-null  object
#  20  purpose                      466285 non-null  object
#  21  title                        466264 non-null  object
#  22  zip_code                     466285 non-null  object
#  23  addr_state                   466285 non-null  object
#  24  dti                          466285 non-null  float64
#  25  delinq_2yrs                  466256 non-null  float64
#  26  earliest_cr_line             466256 non-null  object
#  27  inq_last_6mths               466256 non-null  float64
#  28  mths_since_last_delinq       215934 non-null  float64
#  29  mths_since_last_record       62638 non-null   float64
#  30  open_acc                     466256 non-null  float64
#  31  pub_rec                      466256 non-null  float64
#  32  revol_bal                    466285 non-null  int64
#  33  revol_util                   465945 non-null  float64
#  34  total_acc                    466256 non-null  float64
#  35  initial_list_status          466285 non-null  object
#  36  out_prncp                    466285 non-null  float64
#  37  out_prncp_inv                466285 non-null  float64
#  38  total_pymnt                  466285 non-null  float64
#  39  total_pymnt_inv              466285 non-null  float64
#  40  total_rec_prncp              466285 non-null  float64
#  41  total_rec_int                466285 non-null  float64
#  42  total_rec_late_fee           466285 non-null  float64
#  43  recoveries                   466285 non-null  float64
#  44  collection_recovery_fee      466285 non-null  float64
#  45  last_pymnt_d                 465909 non-null  object
#  46  last_pymnt_amnt              466285 non-null  float64
#  47  next_pymnt_d                 239071 non-null  object
#  48  last_credit_pull_d           466243 non-null  object
#  49  collections_12_mths_ex_med   466140 non-null  float64
#  50  mths_since_last_major_derog  98974 non-null   float64
#  51  policy_code                  466285 non-null  int64
#  52  application_type             466285 non-null  object
#  53  annual_inc_joint             0 non-null       float64
#  54  dti_joint                    0 non-null       float64
#  55  verification_status_joint    0 non-null       float64
#  56  acc_now_delinq               466256 non-null  float64
#  57  tot_coll_amt                 396009 non-null  float64
#  58  tot_cur_bal                  396009 non-null  float64
#  59  open_acc_6m                  0 non-null       float64
#  60  open_il_6m                   0 non-null       float64
#  61  open_il_12m                  0 non-null       float64
#  62  open_il_24m                  0 non-null       float64
#  63  mths_since_rcnt_il           0 non-null       float64
#  64  total_bal_il                 0 non-null       float64
#  65  il_util                      0 non-null       float64
#  66  open_rv_12m                  0 non-null       float64
#  67  open_rv_24m                  0 non-null       float64
#  68  max_bal_bc                   0 non-null       float64
#  69  all_util                     0 non-null       float64
#  70  total_rev_hi_lim             396009 non-null  float64
#  71  inq_fi                       0 non-null       float64
#  72  total_cu_tl                  0 non-null       float64
#  73  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(6), object(22)
# memory usage: 266.8+ MB

# %%
data.sample(2)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 186718   1595321    1865782       6950         6950           6900.0
# 342809  21520773   23853677      18000        18000          18000.0
#
#               term  int_rate  installment grade sub_grade  \
# 186718   36 months      7.90       217.47     A        A4
# 342809   36 months      6.03       547.84     A        A1
#
#                           emp_title emp_length home_ownership  annual_inc  \
# 186718  Narragansett Bay Commission  10+ years            OWN     41500.0
# 342809            Software Engineer    3 years       MORTGAGE     90000.0
#
#        verification_status issue_d loan_status pymnt_plan  \
# 186718            Verified  Nov-12  Fully Paid          n
# 342809        Not Verified  Jul-14     Current          n
#
#                                                       url  \
# 186718  https://www.lendingclub.com/browse/loanDetail....
# 342809  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 186718    Borrower added on 11/07/12 > Im using the lo...  debt_consolidation
# 342809                                                NaN         credit_card
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 186718             Debt release    029xx         RI  28.83          0.0
# 342809  Credit card refinancing    194xx         PA  18.54          0.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 186718           Aug-96             3.0                     NaN
# 342809           Sep-95             0.0                     NaN
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 186718                     NaN      16.0      0.0      22866        59.6
# 342809                     NaN      13.0      0.0      16708        31.1
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 186718       32.0                   f       0.00           0.00   7828.80931
# 342809       21.0                   w    9405.72        9405.72   9861.12000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 186718          7772.49          6950.00         878.81                 0.0
# 342809          9861.12          8594.28        1266.84                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 186718         0.0                      0.0       Nov-15           217.35
# 342809         0.0                      0.0       Jan-16           547.84
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 186718          NaN             Nov-15                         0.0
# 342809       Feb-16             Jan-16                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 186718                          NaN            1       INDIVIDUAL
# 342809                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint  verification_status_joint  \
# 186718               NaN        NaN                        NaN
# 342809               NaN        NaN                        NaN
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 186718             0.0           0.0     184778.0          NaN         NaN
# 342809             0.0           0.0     320895.0          NaN         NaN
#
#         open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 186718          NaN          NaN                 NaN           NaN      NaN
# 342809          NaN          NaN                 NaN           NaN      NaN
#
#         open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 186718          NaN          NaN         NaN       NaN           38382.0
# 342809          NaN          NaN         NaN       NaN           53800.0
#
#         inq_fi  total_cu_tl  inq_last_12m
# 186718     NaN          NaN           NaN
# 342809     NaN          NaN           NaN

# %% [markdown]
# - Terdapat banyak kolom kosong yang tidak mememiliki informasi untuk mengatasinya perlu dilakukan drop akan kolom yang memiliki informasi.
# - terdapat beberapa kolom yang meiliki tipe data yang kurang sesuai perlu dilakukan perbaikan tipe data pada kolom tersebut.

# %%
# menghapus kolom yang tidak memiliki value sama sekali
data= data.dropna(axis=1, how='all')
# cross cek data yang memiliki missing value
data.columns[data.isnull().any()].tolist()
# Out:
# ['emp_title',
#  'emp_length',
#  'annual_inc',
#  'desc',
#  'title',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_util',
#  'total_acc',
#  'last_pymnt_d',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'total_rev_hi_lim']

# %%
data['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
# Perbaikan type data kolom Emp_length
data['emp_length'] = data['emp_length'].str.replace('\+ years','')
data['emp_length'] = data['emp_length'].str.replace('< 1 year',str(0))
data['emp_length'] = data['emp_length'].str.replace(' years','')
data['emp_length'] = data['emp_length'].str.replace(' year','')
data['emp_length'] = data['emp_length'].str.replace('10+','10')

print(data['emp_length'].isnull().sum())
data['emp_length'] = data['emp_length'].fillna(0)

data['emp_length']= data['emp_length'].astype(int)
print(data['emp_length'].info())
# Out:
# 21008
# <class 'pandas.core.series.Series'>
# Index: 466285 entries, 0 to 466284
# Series name: emp_length
# Non-Null Count   Dtype
# --------------   -----
# 466285 non-null  int32
# dtypes: int32(1)
# memory usage: 5.3 MB
# None

# %%
# Perbaikan type data kolom Term
data['term'] = data['term'].str.replace(' months','')
data['term']= data['term'].astype(int)
data['term'].unique()
# Out:
# array([36, 60])

# %%
#Renaming columns
data = data.rename(columns={'member_id': 'Member', 'loan_amnt' : 'Loan Amount', 'funded_amnt':'Funded Amount','funded_amnt_inv':'Amount Investors', 'term':'Tenor', 'int_rate' :'Rate',
                            'installment':'Installment','emp_title':'Employ Title','emp_length':'Employ Length','grade':'Grade','sub_grade':'Sub Grade','home_ownership':'Home Ownership',
                            'annual_inc':'Annual Income','verification_status':'Verification Status','issue_d':'Issue Date','loan_status':'Loan Status','pymnt_plan':'Payment Plan','desc':'Description',
                            'purpose':'Purpose','title':'Title','zip_code':'Zip Code','addr_state':'Addres States','delinq_2yrs':'Delinq 2 Years','mths_since_last_delinq':'Months Last Delinq',
                            'mths_since_last_record':'Months Last Record','open_acc':'Open Accord Credits','pub_rec':'Public Record','total_acc':'Total Accord','initial_list_status':'Initial status',
                            'total_pymnt':'Total Payment','total_pymnt_inv':'Total Payment Investation','last_pymnt_d':'Last Payment Date','last_pymnt_amnt':'Last Payment Amount',
                            'next_pymnt_d':'Next Payment Date','last_credit_pull_d':'Credit Pull Date','policy_code':'Police Code','application_type':'Application Type','acc_now_delinq': 'Accord Now Delinq',
                            'tot_coll_amt':'Total Collection Amount', 'tot_cur_bal':'Total Current Balance','total_rec_prncp':'Total Received Principal','total_rec_int': 'Total Interest Received',
                            'total_rec_late_fee':'Total Received Late','earliest_cr_line':'Earlist Credit Line','inq_last_6mths':'Inquiries Last 6Months','revol_bal':'Revolving Balance',
                            'revol_util':'Revolving Ultilization Rate','recoveries':'Recoveries', 'collection_recovery_fee':'Collection Recovery Fee','collections_12_mths_ex_med':'Collections 12 Months',
                            'mths_since_last_major_derog':'Months Since Recent 90 Day','total_rev_hi_lim':'Total Revolving High Limit','out_prncp':'Outstanding Pricipal',
                            'out_prncp_inv':'Outstanding Pricipal Investors'})
data.sample(2)
# Out:
#               id    Member  Loan Amount  Funded Amount  Amount Investors  \
# 341645  21881079  24214038        28000          28000           27975.0
# 413523  13408712  15461003        18000          18000           18000.0
#
#         Tenor   Rate  Installment Grade Sub Grade           Employ Title  \
# 341645     36   9.17       892.61     B        B1  IT Compliance Sr. Mgr
# 413523     60  15.31       431.16     C        C4       HR/LR Specialist
#
#         Employ Length Home Ownership  Annual Income Verification Status  \
# 341645             10       MORTGAGE       140000.0     Source Verified
# 413523             10       MORTGAGE        82500.0     Source Verified
#
#        Issue Date Loan Status Payment Plan  \
# 341645     Jul-14     Current            n
# 413523     Apr-14     Current            n
#
#                                                       url Description  \
# 341645  https://www.lendingclub.com/browse/loanDetail....         NaN
# 413523  https://www.lendingclub.com/browse/loanDetail....         NaN
#
#                    Purpose                    Title Zip Code Addres States  \
# 341645         credit_card  Credit card refinancing    319xx            GA
# 413523  debt_consolidation       Debt consolidation    451xx            OH
#
#           dti  Delinq 2 Years Earlist Credit Line  Inquiries Last 6Months  \
# 341645  21.75             1.0              Oct-92                     0.0
# 413523   6.55             0.0              Nov-96                     2.0
#
#         Months Last Delinq  Months Last Record  Open Accord Credits  \
# 341645                23.0                 NaN                 18.0
# 413523                 NaN                 NaN                  8.0
#
#         Public Record  Revolving Balance  Revolving Ultilization Rate  \
# 341645            0.0              49095                         66.6
# 413523            0.0              10603                         31.1
#
#         Total Accord Initial status  Outstanding Pricipal  \
# 341645          41.0              f              15730.09
# 413523          21.0              w              13182.15
#
#         Outstanding Pricipal Investors  Total Payment  \
# 341645                        15716.04       15174.37
# 413523                        13182.15        9054.36
#
#         Total Payment Investation  Total Received Principal  \
# 341645                   15160.82                  12269.91
# 413523                    9054.36                   4817.85
#
#         Total Interest Received  Total Received Late  Recoveries  \
# 341645                  2904.46                  0.0         0.0
# 413523                  4236.51                  0.0         0.0
#
#         Collection Recovery Fee Last Payment Date  Last Payment Amount  \
# 341645                      0.0            Dec-15               892.61
# 413523                      0.0            Jan-16               431.16
#
#        Next Payment Date Credit Pull Date  Collections 12 Months  \
# 341645            Feb-16           Jan-16                    0.0
# 413523            Feb-16           Jan-16                    0.0
#
#         Months Since Recent 90 Day  Police Code Application Type  \
# 341645                         NaN            1       INDIVIDUAL
# 413523                         NaN            1       INDIVIDUAL
#
#         Accord Now Delinq  Total Collection Amount  Total Current Balance  \
# 341645                0.0                      0.0               261755.0
# 413523                0.0                     50.0                10603.0
#
#         Total Revolving High Limit
# 341645                     73700.0
# 413523                     34100.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 466285 entries, 0 to 466284
# Data columns (total 57 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              466285 non-null  int64
#  1   Member                          466285 non-null  int64
#  2   Loan Amount                     466285 non-null  int64
#  3   Funded Amount                   466285 non-null  int64
#  4   Amount Investors                466285 non-null  float64
#  5   Tenor                           466285 non-null  int32
#  6   Rate                            466285 non-null  float64
#  7   Installment                     466285 non-null  float64
#  8   Grade                           466285 non-null  object
#  9   Sub Grade                       466285 non-null  object
#  10  Employ Title                    438697 non-null  object
#  11  Employ Length                   466285 non-null  int32
#  12  Home Ownership                  466285 non-null  object
#  13  Annual Income                   466281 non-null  float64
#  14  Verification Status             466285 non-null  object
#  15  Issue Date                      466285 non-null  object
#  16  Loan Status                     466285 non-null  object
#  17  Payment Plan                    466285 non-null  object
#  18  url                             466285 non-null  object
#  19  Description                     125981 non-null  object
#  20  Purpose                         466285 non-null  object
#  21  Title                           466264 non-null  object
#  22  Zip Code                        466285 non-null  object
#  23  Addres States                   466285 non-null  object
#  24  dti                             466285 non-null  float64
#  25  Delinq 2 Years                  466256 non-null  float64
#  26  Earlist Credit Line             466256 non-null  object
#  27  Inquiries Last 6Months          466256 non-null  float64
#  28  Months Last Delinq              215934 non-null  float64
#  29  Months Last Record              62638 non-null   float64
#  30  Open Accord Credits             466256 non-null  float64
#  31  Public Record                   466256 non-null  float64
#  32  Revolving Balance               466285 non-null  int64
#  33  Revolving Ultilization Rate     465945 non-null  float64
#  34  Total Accord                    466256 non-null  float64
#  35  Initial status                  466285 non-null  object
#  36  Outstanding Pricipal            466285 non-null  float64
#  37  Outstanding Pricipal Investors  466285 non-null  float64
#  38  Total Payment                   466285 non-null  float64
#  39  Total Payment Investation       466285 non-null  float64
#  40  Total Received Principal        466285 non-null  float64
#  41  Total Interest Received         466285 non-null  float64
#  42  Total Received Late             466285 non-null  float64
#  43  Recoveries                      466285 non-null  float64
#  44  Collection Recovery Fee         466285 non-null  float64
#  45  Last Payment Date               465909 non-null  object
#  46  Last Payment Amount             466285 non-null  float64
#  47  Next Payment Date               239071 non-null  object
#  48  Credit Pull Date                466243 non-null  object
#  49  Collections 12 Months           466140 non-null  float64
#  50  Months Since Recent 90 Day      98974 non-null   float64
#  51  Police Code                     466285 non-null  int64
#  52  Application Type                466285 non-null  object
#  53  Accord Now Delinq               466256 non-null  float64
#  54  Total Collection Amount         396009 non-null  float64
#  55  Total Current Balance           396009 non-null  float64
#  56  Total Revolving High Limit      396009 non-null  float64
# dtypes: float64(29), int32(2), int64(6), object(20)
# memory usage: 202.8+ MB

# %%
data['Issue Date'] = data['Issue Date'].str.split('-').str[0]
data['Last Payment Date'] = data['Last Payment Date'].str.split('-').str[0]
data['Credit Pull Date'] = data['Credit Pull Date'].str.split('-').str[0]
data['Earlist Credit Line'] = data['Earlist Credit Line'].str.split('-').str[1]

# %%
def fill_columns_with_mode(data, col):
    for column in col:
        if column in data.columns:
            mode_value = data[column].mode().values[0]
            data[column].fillna(mode_value, inplace=True)

    return data

fill_columns_with_mode(data,['Issue Date','Last Payment Date','Credit Pull Date'] )
print(data['Issue Date'].isnull().sum())
print(data['Last Payment Date'].isnull().sum())
print(data['Credit Pull Date'].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
data['Earlist Credit Line'] = data['Earlist Credit Line'].fillna(0)
data['Earlist Credit Line'] = data['Earlist Credit Line'].astype(int)
data['Earlist Credit Line'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 466285 entries, 0 to 466284
# Series name: Earlist Credit Line
# Non-Null Count   Dtype
# --------------   -----
# 466285 non-null  int32
# dtypes: int32(1)
# memory usage: 5.3 MB

# %%
# Tabel kontogensi pinjaman, status pinjaman, dengan tujuan pinjaman
pd.crosstab(data['Purpose'], data['Loan Status'], values=data['Loan Amount'], aggfunc='mean').round(2).sort_values(by='Charged Off', ascending=False)
# Out:
# Loan Status         Charged Off   Current   Default  \
# Purpose
# small_business         16202.57  15868.20  20019.23
# debt_consolidation     15321.13  15892.75  15808.82
# home_improvement       15027.38  14410.18  15976.67
# house                  14768.82  14886.17  19862.50
# credit_card            14719.33  15530.89  14724.22
# major_purchase         11803.59  11650.76  13333.33
# wedding                11634.34  11686.07       NaN
# renewable_energy       10964.22  10846.74       NaN
# other                  10080.17   9896.17  11376.11
# medical                 9198.85   9062.53  12628.12
# car                     8665.24   8853.74  14790.00
# moving                  7968.83   7879.36   9500.00
# educational             7858.93       NaN       NaN
# vacation                6900.10   6435.61   4760.00
#
# Loan Status         Does not meet the credit policy. Status:Charged Off  \
# Purpose
# small_business                                               15044.44
# debt_consolidation                                            9739.13
# home_improvement                                              9507.75
# house                                                         7993.18
# credit_card                                                  10705.80
# major_purchase                                                8327.17
# wedding                                                       8815.38
# renewable_energy                                              5000.00
# other                                                         7660.95
# medical                                                       6473.86
# car                                                           8561.54
# moving                                                        6171.67
# educational                                                   6425.78
# vacation                                                      5250.00
#
# Loan Status         Does not meet the credit policy. Status:Fully Paid  \
# Purpose
# small_business                                               14194.38
# debt_consolidation                                           10156.19
# home_improvement                                              9010.31
# house                                                         7807.58
# credit_card                                                   9528.51
# major_purchase                                                6286.75
# wedding                                                       7267.44
# renewable_energy                                              6000.00
# other                                                         6323.93
# medical                                                       6055.56
# car                                                           5840.20
# moving                                                        5760.48
# educational                                                   5805.77
# vacation                                                      4711.54
#
# Loan Status         Fully Paid  In Grace Period  Late (16-30 days)  \
# Purpose
# small_business        14482.24         17053.98           14115.91
# debt_consolidation    14102.38         16648.89           16590.97
# home_improvement      13078.91         17319.69           15742.16
# house                 15298.69         12294.44           22506.25
# credit_card           13560.71         16257.96           15718.84
# major_purchase         9337.34         15066.80           14005.43
# wedding               10133.90         11400.00                NaN
# renewable_energy       9421.50         13116.67                NaN
# other                  9021.30         11545.95           10851.43
# medical                8556.99          9067.97            8981.25
# car                    7542.89         11982.81           14385.71
# moving                 7158.56          8235.00           10075.00
# educational            6592.19              NaN                NaN
# vacation               5528.41          5535.00           11016.67
#
# Loan Status         Late (31-120 days)
# Purpose
# small_business                17895.05
# debt_consolidation            16024.10
# home_improvement              16029.70
# house                         15088.97
# credit_card                   15720.06
# major_purchase                13658.08
# wedding                       14203.57
# renewable_energy              10937.50
# other                         10991.57
# medical                       11154.76
# car                           10386.18
# moving                         9030.81
# educational                        NaN
# vacation                       7490.52

# %% [markdown]
# Penjelasannya :
# - Untuk status pinjam **pembayaran penuh (full- paid)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **Rumah**.
# -  Untuk status pinjam **dikenai biaya (Charged Off)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **small  bussines**.
# - Untuk status pinjam **masih berjalan (Current)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **debt consolidation**.
# - Untuk status pinjam **gagal bayar (Default)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **small bussines**.
# - Untuk status pinjam **tidak memenuhi kebijakan kredit status dikenai biaya (Does not meet the credit policy. Status:Charged Off)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **small bussines**.
# - Untuk status pinjam **tidak memenuhi kebijakan kredit status dibayar penuh (Does not meet the credit policy. Status:fully paid)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **small bussines**.
# - Untuk status pinjam **Dalam masa tenggang (in-grace period)**yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **perbaikan Rumah**.
# - Untuk status pinjam **terlambat 2 minggu- 1 bulan (late 16-30 )** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **Rumah**.
# - Untuk status pinjam **terlambat 1 bulan - 4 bulan (late 31-120)** yang memiliki rata-rata tertinggi pembayaran bulan lalu adalah yang memiliki tujuan pinjaman **small bussines**.

# %% [markdown]
# ### KESIMPULAN
# Yang memiliki tujuan pinjaman **Small Bussines** memiliki potensi buruk terhadap pembayaran.

# %%
# tabel kontingensi antara tujuan dengan status pinjaman
pd.crosstab( data['Loan Status'] , data['Purpose'], margins=False).nlargest(10, columns='wedding')
# Out:
# Purpose                                              car  credit_card  \
# Loan Status
# Fully Paid                                          2966        38169
# Current                                             1876        55892
# Charged Off                                          425         7380
# Does not meet the credit policy. Status:Fully Paid    51          271
# Does not meet the credit policy. Status:Charged...    13           69
# Late (31-120 days)                                    38         1371
# In Grace Period                                       16          625
# Default                                                5          161
# Late (16-30 days)                                      7          219
#
# Purpose                                             debt_consolidation  \
# Loan Status
# Fully Paid                                                      106441
# Current                                                         133134
# Charged Off                                                      25835
# Does not meet the credit policy. Status:Fully Paid                 808
# Does not meet the credit policy. Status:Charged...                 292
# Late (31-120 days)                                                4398
# In Grace Period                                                   1976
# Default                                                            544
# Late (16-30 days)                                                  767
#
# Purpose                                             educational  \
# Loan Status
# Fully Paid                                                  269
# Current                                                       0
# Charged Off                                                  56
# Does not meet the credit policy. Status:Fully Paid           65
# Does not meet the credit policy. Status:Charged...           32
# Late (31-120 days)                                            0
# In Grace Period                                               0
# Default                                                       0
# Late (16-30 days)                                             0
#
# Purpose                                             home_improvement  house  \
# Loan Status
# Fully Paid                                                     11076   1182
# Current                                                        12453    714
# Charged Off                                                     2126    267
# Does not meet the credit policy. Status:Fully Paid               143     33
# Does not meet the credit policy. Status:Charged...                71     11
# Late (31-120 days)                                               378     34
# In Grace Period                                                  193     18
# Default                                                           30      6
# Late (16-30 days)                                                 67      4
#
# Purpose                                             major_purchase  medical  \
# Loan Status
# Fully Paid                                                    4912     2054
# Current                                                       3790     1856
# Charged Off                                                    808      523
# Does not meet the credit policy. Status:Fully Paid             100       36
# Does not meet the credit policy. Status:Charged...              23       22
# Late (31-120 days)                                              99       63
# In Grace Period                                                 64       32
# Default                                                          9        8
# Late (16-30 days)                                               23        8
#
# Purpose                                             moving  other  \
# Loan Status
# Fully Paid                                            1404  10063
# Current                                               1079   9843
# Charged Off                                            393   2771
# Does not meet the credit policy. Status:Fully Paid      31    303
# Does not meet the credit policy. Status:Charged...      15    121
# Late (31-120 days)                                      43    332
# In Grace Period                                         15    142
# Default                                                  6     45
# Late (16-30 days)                                        8     70
#
# Purpose                                             renewable_energy  \
# Loan Status
# Fully Paid                                                       200
# Current                                                           92
# Charged Off                                                       51
# Does not meet the credit policy. Status:Fully Paid                 2
# Does not meet the credit policy. Status:Charged...                 1
# Late (31-120 days)                                                 2
# In Grace Period                                                    3
# Default                                                            0
# Late (16-30 days)                                                  0
#
# Purpose                                             small_business  vacation  \
# Loan Status
# Fully Paid                                                    3164      1150
# Current                                                       2170      1004
# Charged Off                                                   1322       253
# Does not meet the credit policy. Status:Fully Paid              89        13
# Does not meet the credit policy. Status:Charged...              72         6
# Late (31-120 days)                                             106        29
# In Grace Period                                                 44        15
# Default                                                         13         5
# Late (16-30 days)                                               33        12
#
# Purpose                                             wedding
# Loan Status
# Fully Paid                                             1689
# Current                                                 323
# Charged Off                                             265
# Does not meet the credit policy. Status:Fully Paid       43
# Does not meet the credit policy. Status:Charged...       13
# Late (31-120 days)                                        7
# In Grace Period                                           3
# Default                                                   0
# Late (16-30 days)                                         0

# %% [markdown]
# Kesimpulan nasabah dengan tujuan debt consolidation cenderung akan masuk ke daftar status pembayaran kurang baik.

# %%
# tabel kontigensi lamanya tenor dengan status pinjaman
pd.crosstab(data['Tenor'], data['Loan Status'], margins=True).sort_values(by='All',ascending=False)
# Out:
# Loan Status  Charged Off  Current  Default  \
# Tenor
# All                42475   224226      832
# 36                 27455   149505      490
# 60                 15020    74721      342
#
# Loan Status  Does not meet the credit policy. Status:Charged Off  \
# Tenor
# All                                                        761
# 36                                                         649
# 60                                                         112
#
# Loan Status  Does not meet the credit policy. Status:Fully Paid  Fully Paid  \
# Tenor
# All                                                       1988       184739
# 36                                                        1789       151101
# 60                                                         199        33638
#
# Loan Status  In Grace Period  Late (16-30 days)  Late (31-120 days)     All
# Tenor
# All                     3146               1218                6900  466285
# 36                      1979                769                4216  337953
# 60                      1167                449                2684  128332

# %% [markdown]
# Nasabah lebih banyak menggunakan tenor 36x dibanding 60x.

# %%
result = pd.crosstab(data['Rate'], data['Tenor'], margins=False)
top_10 = result.nlargest(10, columns=[36])
Top_10 = result.nlargest(10, columns=[60])
print('Tenor =36')
print(top_10)
print()
print('Tenor =60')
print(Top_10)
# Out:
# Tenor =36
# Tenor     36    60
# Rate
# 10.99  13274  1563
# 12.99  12501  3345
# 8.90   10777   647
# 7.90    9983    96
# 6.03    9846     0
# 11.99   9021  1093
# 12.12   8579   835
# 12.49   8329  1398
# 13.11   7507   954
# 15.61   7049  6025
#
# Tenor =60
# Tenor     36    60
# Rate
# 15.61   7049  6025
# 17.57   3687  4427
# 16.29   6185  4402
# 12.99  12501  3345
# 14.99   4890  3213
# 16.99   3173  3213
# 13.98   6774  3029
# 14.49   4230  3013
# 19.52   2356  2545
# 15.31   6011  2285

# %% [markdown]
# - Setelah dilakukan analisa didapat untuk tenor 36 nasabah cendrung menggunakan rate kisaran 6.03 - 15.61 %.
# - Sedangkan pada tenor 60 nasabah cenderung menggunakan Rate 13 % keatas.

# %%
# tabel kontigensi status kepemilikan, status pinjaman dengan pendapatan tahunan.
pd.crosstab(data['Home Ownership'], data['Loan Status'], values=data['Annual Income'], aggfunc='mean').round(2)
# Out:
# Loan Status     Charged Off   Current   Default  \
# Home Ownership
# ANY                     NaN       NaN       NaN
# MORTGAGE           74293.55  84473.02  75169.58
# NONE               48685.71  80000.00       NaN
# OTHER              59696.70  65993.33       NaN
# OWN                58723.39  67221.07  54850.97
# RENT               56881.56  63247.98  59271.40
#
# Loan Status     Does not meet the credit policy. Status:Charged Off  \
# Home Ownership
# ANY                                                           NaN
# MORTGAGE                                                 91328.28
# NONE                                                     72000.00
# OTHER                                                    38220.55
# OWN                                                      77313.30
# RENT                                                     47858.53
#
# Loan Status     Does not meet the credit policy. Status:Fully Paid  \
# Home Ownership
# ANY                                                           NaN
# MORTGAGE                                                 92756.31
# NONE                                                          NaN
# OTHER                                                    69151.48
# OWN                                                      60047.82
# RENT                                                     53523.71
#
# Loan Status     Fully Paid  In Grace Period  Late (16-30 days)  \
# Home Ownership
# ANY               35680.00              NaN                NaN
# MORTGAGE          84013.96         84074.56           82412.25
# NONE              65529.19              NaN                NaN
# OTHER             70492.03              NaN                NaN
# OWN               65548.92         68870.57           63051.15
# RENT              62730.58         64532.56           62270.98
#
# Loan Status     Late (31-120 days)
# Home Ownership
# ANY                            NaN
# MORTGAGE                  79571.61
# NONE                           NaN
# OTHER                          NaN
# OWN                       64114.38
# RENT                      60023.41

# %% [markdown]
# Untuk pendapatan tahunan tertinggi dari nasabah yang meminjam ada pada Status Kepemilikan ** Mortgage**.

# %%
# Tabel Kontigensi Loan status dengan Home Ownership
pd.crosstab(data['Loan Status'], data['Home Ownership'], values=data['Employ Length'], aggfunc='mean')
# Out:
# Home Ownership                                      ANY  MORTGAGE       NONE  \
# Loan Status
# Charged Off                                         NaN  6.218948   4.428571
# Current                                             NaN  6.525282  10.000000
# Default                                             NaN  6.247863        NaN
# Does not meet the credit policy. Status:Charged...  NaN  5.362069   6.000000
# Does not meet the credit policy. Status:Fully Paid  NaN  5.038546   0.000000
# Fully Paid                                          5.0  6.355896   6.694444
# In Grace Period                                     NaN  6.544148        NaN
# Late (16-30 days)                                   NaN  6.056013        NaN
# Late (31-120 days)                                  NaN  6.369510        NaN
#
# Home Ownership                                          OTHER       OWN  \
# Loan Status
# Charged Off                                          4.888889  5.292024
# Current                                             10.000000  5.833772
# Default                                                   NaN  5.144928
# Does not meet the credit policy. Status:Charged...   3.000000  5.775510
# Does not meet the credit policy. Status:Fully Paid   3.148148  3.949275
# Fully Paid                                           4.403509  5.564529
# In Grace Period                                           NaN  5.699029
# Late (16-30 days)                                         NaN  5.796875
# Late (31-120 days)                                        NaN  5.465961
#
# Home Ownership                                          RENT
# Loan Status
# Charged Off                                         4.845223
# Current                                             5.036945
# Default                                             5.410194
# Does not meet the credit policy. Status:Charged...  3.539773
# Does not meet the credit policy. Status:Fully Paid  3.010977
# Fully Paid                                          4.685248
# In Grace Period                                     4.976017
# Late (16-30 days)                                   4.815735
# Late (31-120 days)                                  4.940911

# %% [markdown]
# Karakteristik nasabah yang meminjam adalah nasabah yang sudah bekerja diatas 3.5 tahun.

# %%
pd.crosstab(data['Home Ownership'],data['Employ Length'],values=data['Rate'], aggfunc='mean').round(2)
# Out:
# Employ Length      0      1      2      3      4      5      6      7      8   \
# Home Ownership
# ANY               NaN    NaN    NaN    NaN    NaN  11.67    NaN    NaN    NaN
# MORTGAGE        13.41  13.43  13.39  13.42  13.41  13.44  13.60  13.66  13.54
# NONE            12.27  18.52  11.62  12.12  19.05  11.53  12.33  12.70  15.31
# OTHER           13.35  13.26  13.97  14.11  12.78  12.64  12.57  13.87  12.44
# OWN             13.86  13.91  13.93  13.88  13.98  14.10  13.93  13.98  14.06
# RENT            13.96  13.78  13.88  13.88  13.93  14.12  14.16  14.36  14.32
#
# Employ Length      9      10
# Home Ownership
# ANY               NaN    NaN
# MORTGAGE        13.57  13.68
# NONE            14.74  16.79
# OTHER           16.85  13.52
# OWN             14.03  13.92
# RENT            14.37  14.60

# %% [markdown]
# Suku bunga yang paling diminati dilihat dari tahun kerja nasabah rata-rata dikisaran diatas 12%

# %%
# Tabel kontigensi grade, status verifikasi berdasarkan jumlah tertinggi nasabah
pd.crosstab(data['Grade'],data['Verification Status'],values=data['id'], aggfunc='count')
# Out:
# Verification Status  Not Verified  Source Verified  Verified
# Grade
# A                           33233            22636     18998
# B                           53583            40421     42925
# C                           35807            41781     47705
# D                           18663            27116     31109
# E                            5256            12863     17638
# F                            1407             4175      7647
# G                             288             1001      2033

# %% [markdown]
# Dari ketiga jenis status verifikasi dikonfirmasi bahwa grade **B dan C** memiliki dampak besar.

# %%
# tabel kontigensi Pendapatan tahunan , kenakalan 2 tahun terakhir dan grade
pd.crosstab(data['Grade'],data['Delinq 2 Years'],values=data['Annual Income'], aggfunc='mean')
# Out:
# Delinq 2 Years          0.0           1.0           2.0            3.0   \
# Grade
# A               81460.797058  91871.247664  96621.551615  102072.000000
# B               70844.405285  77496.431763  83001.218705   84811.086172
# C               68376.215672  76201.749690  80462.907701   85498.590734
# D               67402.110151  76969.061330  80446.082287   85557.586229
# E               70840.406836  79928.859144  87796.411389   84352.959059
# F               72683.442937  82961.606711  82814.239583   89685.472574
# G               83745.633079  91746.281023  90640.101605  103229.128571
#
# Delinq 2 Years          4.0            5.0            6.0            7.0   \
# Grade
# A               90832.614035   90377.333333   82231.187500  103979.166667
# B               86555.955346   83999.130814   81547.455939   80696.345000
# C               85403.545548   86551.298022   77071.660258   78462.507685
# D               82381.398618   83342.014745   76125.397351   92793.802658
# E               84710.628930   80145.870690  103869.540984   99137.666667
# F               89222.554800   97085.846154   82742.222222  113077.230769
# G               83869.125000  169333.333333  103977.500000   71000.000000
#
# Delinq 2 Years           8.0           9.0            10.0           11.0  \
# Grade
# A               101000.000000  89142.857143   83000.000000   62500.000000
# B                88786.909091  84634.666667  114922.222222   89718.461538
# C                84180.098361  90500.360000   87033.565217   77893.076923
# D                83976.388889  89308.284706  107149.857143   53679.500000
# E                93491.752000  96468.985455  110000.000000   44848.000000
# F                81582.428571  94000.000000  107500.000000   51000.000000
# G                75000.000000  56800.000000            NaN  220000.000000
#
# Delinq 2 Years          12.0           13.0      14.0           15.0     16.0  \
# Grade
# A               90000.000000  131500.000000       NaN            NaN  82746.0
# B               85150.000000   66666.666667       NaN   47000.000000  66500.0
# C               64406.600000  127089.000000   56100.0   69833.333333  57000.0
# D               65666.666667   61134.000000   48000.0  100000.000000  80000.0
# E               67140.000000   77000.000000  101500.0   85000.000000      NaN
# F                        NaN            NaN       NaN            NaN      NaN
# G               74250.000000   93000.000000       NaN            NaN      NaN
#
# Delinq 2 Years      17.0      18.0     19.0     21.0     22.0     24.0  \
# Grade
# A                    NaN       NaN      NaN      NaN      NaN      NaN
# B                    NaN  105000.0  47500.0  67260.0      NaN  98000.0
# C                    NaN   81000.0  88282.5  32646.0  67577.5      NaN
# D                81000.0   49000.0      NaN      NaN      NaN      NaN
# E                    NaN  100000.0      NaN      NaN      NaN      NaN
# F               110000.0       NaN      NaN      NaN      NaN      NaN
# G                    NaN       NaN      NaN      NaN      NaN      NaN
#
# Delinq 2 Years     29.0
# Grade
# A                   NaN
# B                   NaN
# C               51500.0
# D                   NaN
# E                   NaN
# F                   NaN
# G                   NaN

# %% [markdown]
# - Dilihat dari pendapatan tahunan nasabah yang melakukan kenakalan **19-29 kali** dalam kurung waktu kurang dari 2 tahun adalah **grade B dan C**, memiliki rata-rata pendapatan di kisaran 30-80.
#
# - **Semakin tinggi Pendapatan tahunan** nasabah menunjukan semakin **kecil jumlah kenakalan dalam 2 tahun terakhir**.

# %%
# tabel kontigensi Grade, Sub Grade berdasarkan rata-rata Suku bunga
pd.crosstab(data['Grade'],data['Sub Grade'],values=data['Rate'], aggfunc='mean')
# Out:
# Sub Grade        A1        A2        A3        A4        A5       B1  \
# Grade
# A          6.006046  6.552704  7.388607  7.796832  8.638248      NaN
# B               NaN       NaN       NaN       NaN       NaN  9.62653
# C               NaN       NaN       NaN       NaN       NaN      NaN
# D               NaN       NaN       NaN       NaN       NaN      NaN
# E               NaN       NaN       NaN       NaN       NaN      NaN
# F               NaN       NaN       NaN       NaN       NaN      NaN
# G               NaN       NaN       NaN       NaN       NaN      NaN
#
# Sub Grade         B2         B3         B4         B5         C1         C2  \
# Grade
# A                NaN        NaN        NaN        NaN        NaN        NaN
# B          10.660027  11.592758  12.358864  12.946059        NaN        NaN
# C                NaN        NaN        NaN        NaN  13.525126  14.106759
# D                NaN        NaN        NaN        NaN        NaN        NaN
# E                NaN        NaN        NaN        NaN        NaN        NaN
# F                NaN        NaN        NaN        NaN        NaN        NaN
# G                NaN        NaN        NaN        NaN        NaN        NaN
#
# Sub Grade         C3         C4         C5         D1         D2         D3  \
# Grade
# A                NaN        NaN        NaN        NaN        NaN        NaN
# B                NaN        NaN        NaN        NaN        NaN        NaN
# C          14.681571  15.249956  15.894034        NaN        NaN        NaN
# D                NaN        NaN        NaN  16.521458  17.121836  17.657839
# E                NaN        NaN        NaN        NaN        NaN        NaN
# F                NaN        NaN        NaN        NaN        NaN        NaN
# G                NaN        NaN        NaN        NaN        NaN        NaN
#
# Sub Grade         D4         D5         E1         E2         E3         E4  \
# Grade
# A                NaN        NaN        NaN        NaN        NaN        NaN
# B                NaN        NaN        NaN        NaN        NaN        NaN
# C                NaN        NaN        NaN        NaN        NaN        NaN
# D          18.212148  18.885137        NaN        NaN        NaN        NaN
# E                NaN        NaN  19.385469  20.025899  20.626064  21.329663
# F                NaN        NaN        NaN        NaN        NaN        NaN
# G                NaN        NaN        NaN        NaN        NaN        NaN
#
# Sub Grade         E5         F1         F2         F3         F4         F5  \
# Grade
# A                NaN        NaN        NaN        NaN        NaN        NaN
# B                NaN        NaN        NaN        NaN        NaN        NaN
# C                NaN        NaN        NaN        NaN        NaN        NaN
# D                NaN        NaN        NaN        NaN        NaN        NaN
# E          22.046304        NaN        NaN        NaN        NaN        NaN
# F                NaN  22.845919  23.319297  23.845428  24.163861  24.485512
# G                NaN        NaN        NaN        NaN        NaN        NaN
#
# Sub Grade         G1         G2         G3         G4         G5
# Grade
# A                NaN        NaN        NaN        NaN        NaN
# B                NaN        NaN        NaN        NaN        NaN
# C                NaN        NaN        NaN        NaN        NaN
# D                NaN        NaN        NaN        NaN        NaN
# E                NaN        NaN        NaN        NaN        NaN
# F                NaN        NaN        NaN        NaN        NaN
# G          24.824283  24.929721  25.035094  24.589052  24.659247

# %%
data.groupby('Grade').agg({'Rate':'mean'})
# Out:
#             Rate
# Grade
# A       7.538624
# B      11.503253
# C      14.634089
# D      17.540598
# E      20.487115
# F      23.551352
# G      24.838393

# %%
data.groupby(['Grade','Sub Grade']).agg({'Earlist Credit Line':'count'}).sort_values(by ='Earlist Credit Line')
# Out:
#                  Earlist Credit Line
# Grade Sub Grade
# G     G5                         385
#       G4                         422
#       G3                         583
#       G2                         823
#       G1                        1109
# F     F5                        1513
#       F4                        2067
#       F3                        2708
#       F2                        3001
#       F1                        3940
# E     E5                        5087
#       E4                        5992
#       E3                        6976
#       E2                        8669
#       E1                        9033
# A     A1                       10541
#       A2                       10956
# D     D5                       11566
# A     A3                       12568
# D     D4                       14099
#       D3                       14916
#       D2                       17046
# A     A4                       19045
# D     D1                       19261
# A     A5                       21757
# C     C5                       22178
# B     B1                       22876
# C     C4                       24105
# B     B5                       25252
# C     C3                       25317
# B     B2                       26610
# C     C2                       26740
#       C1                       26953
# B     B4                       30505
#       B3                       31686

# %%
gradeB =data[data['Grade']=='B']
gradeB['Earlist Credit Line'].unique()
# Out:
# array([85, 96,  4, 89,  3, 91, 83,  1,  2, 84,  6,  5,  0,  7, 99, 92, 97,
#        98, 90, 95, 93, 80, 94, 86, 79, 82, 88, 87, 76, 75, 78, 81,  8, 72,
#        77, 67, 65, 70, 73, 71, 69, 74, 62, 64, 63, 66, 68, 56, 46, 50, 61,
#         9, 10, 60, 57, 53, 59, 55, 51, 11, 58, 49, 54])

# %%
gradeB3 =data[data['Sub Grade']=='B3']
gradeB3['Earlist Credit Line'].unique()
# Out:
# array([ 3, 85,  1, 84,  6, 96, 90,  7,  2, 86, 79,  5, 98, 95,  4,  0, 91,
#        94, 99, 87, 97, 89, 92, 88, 93, 77, 81,  8, 71, 75, 74, 83, 82, 76,
#        78, 73, 67, 80, 64, 72, 70, 56, 69, 50, 61, 10,  9, 65, 68, 66, 62,
#        60, 63, 11, 46, 54, 58, 53])

# %%
gradeB3.groupby('Earlist Credit Line').agg({'Sub Grade':'count'})
# Out:
#                      Sub Grade
# Earlist Credit Line
# 0                         2395
# 1                         2372
# 2                         2007
# 3                         1612
# 4                         1414
# 5                         1210
# 6                         1038
# 7                          829
# 8                          418
# 9                          171
# 10                         106
# 11                          33
# 46                           1
# 50                           1
# 53                           1
# 54                           1
# 56                           1
# 58                           1
# 60                           1
# 61                           1
# 62                           3
# 63                           3
# 64                          14
# 65                          12
# 66                          12
# 67                          17
# 68                          16
# 69                          21
# 70                          37
# 71                          35
# 72                          53
# 73                          53
# 74                          72
# 75                          67
# 76                          92
# 77                         118
# 78                         145
# 79                         131
# 80                         145
# 81                         162
# 82                         209
# 83                         293
# 84                         352
# 85                         385
# 86                         412
# 87                         489
# 88                         585
# 89                         689
# 90                         747
# 91                         724
# 92                         734
# 93                         991
# 94                        1379
# 95                        1433
# 96                        1595
# 97                        1582
# 98                        1965
# 99                        2301

# %% [markdown]
# Nasabah yang memiliki sub grade B3 merupakan pelanggan yang mampunyai Earlist Credit Line yang bagus. Hal ini bisa menjadi acuan untuk mengetahui Credit skor terbaik dari nasabah itu sendiri. Semakin lama Earlist Credit Line maka semakin bagus nilai credit skor karena sudah memiliki pengalaman baik terhadap kartu kredit.

# %%
data.groupby(['Grade','Sub Grade']).agg({'Inquiries Last 6Months':'count'}).sort_values(by ='Inquiries Last 6Months')
# Out:
#                  Inquiries Last 6Months
# Grade Sub Grade
# G     G5                            385
#       G4                            422
#       G3                            583
#       G2                            823
#       G1                           1109
# F     F5                           1513
#       F4                           2067
#       F3                           2708
#       F2                           3001
#       F1                           3940
# E     E5                           5087
#       E4                           5992
#       E3                           6975
#       E2                           8669
#       E1                           9033
# A     A1                          10540
#       A2                          10953
# D     D5                          11566
# A     A3                          12564
# D     D4                          14099
#       D3                          14915
#       D2                          17046
# A     A4                          19044
# D     D1                          19261
# A     A5                          21755
# C     C5                          22178
# B     B1                          22876
# C     C4                          24102
# B     B5                          25250
# C     C3                          25316
# B     B2                          26608
# C     C2                          26740
#       C1                          26951
# B     B4                          30502
#       B3                          31683

# %%
gradeB =data[data['Grade']=='B']
gradeB['Inquiries Last 6Months'].unique()
# Out:
# array([ 1.,  0.,  2.,  3.,  4.,  5.,  6.,  7.,  8., 11., 15.,  9., 17.,
#        12., 16., 13., nan])

# %%
gradeB3 =data[data['Sub Grade']=='B3']
gradeB3['Inquiries Last 6Months'].unique()
# Out:
# array([ 0.,  1.,  3.,  2.,  4.,  5.,  6.,  8., 11., 16., nan,  7.])

# %%
gradeB3.groupby('Inquiries Last 6Months').agg({'Sub Grade':'count'})
# Out:
#                         Sub Grade
# Inquiries Last 6Months
# 0.0                         19723
# 1.0                          7585
# 2.0                          2918
# 3.0                          1059
# 4.0                           279
# 5.0                            80
# 6.0                            34
# 7.0                             2
# 8.0                             1
# 11.0                            1
# 16.0                            1

# %% [markdown]
# setelah dilakukan analisa untuk sub grade B3 yang memiliki Earlist Credit Line yang baik, ternyata jarang dilakukan Inquiries Last 6Months(diajukan pertanyaan oleh pihak bank) dikarenakan memiliki skor kredit yang cukup baik. Namun hal ini harus di review untuk melihat perkembangan nasabah itu sendiri untuk menghindari resiko.

# %%
data.groupby('Grade').agg({'Collections 12 Months':'count'})
# Out:
#        Collections 12 Months
# Grade
# A                      74832
# B                     136900
# C                     125266
# D                      76871
# E                      35739
# F                      13217
# G                       3315

# %%
collectionB = data[data['Grade']=='B']
collectionB.groupby('Collections 12 Months').agg({'Grade':'count'})
# Out:
#                         Grade
# Collections 12 Months
# 0.0                    135894
# 1.0                       942
# 2.0                        58
# 3.0                         4
# 4.0                         1
# 5.0                         1

# %%
collectionC = data[data['Grade']=='C']
collectionC.groupby('Collections 12 Months').agg({'Grade':'count'})
# Out:
#                         Grade
# Collections 12 Months
# 0.0                    124050
# 1.0                      1130
# 2.0                        74
# 3.0                         8
# 4.0                         2
# 6.0                         1
# 20.0                        1

# %% [markdown]
# Dari hasil analisa Grade B dan C merupakan nasabah yang memiliki menejemen keuangan yang baik terlihat dari jumlah Collections 12 Months yang rendah mendominasi nasabah Grade B dan C

# %% [markdown]
# ### Kesimpulan
#
# Dari beberapa analisa yang dilakukan untuk Grade B dan C merupakan nasabah yang memiliki potensi tinggi, dari segi pengahasilan tahunan, catatan keterlambatan yang rendah, dan memiliki skor kredit yang baik. Skor kredit yang baik ini dilihat dari tahun pertama penggunaan kartu kredit pertama kalinya. semakin lama tahun tersebut maka akan menggambarkan semakin lama juga pengalaman nasabah dalam menggunakan kartu kredit.

# %%
data['Collections 12 Months'].unique()
# Out:
# array([ 0., nan,  1.,  2.,  4.,  3.,  6., 16., 20.,  5.])

# %%
cat_df=data.select_dtypes(include='object')
Num_df= data.select_dtypes(exclude='object')
cat_df.sample(2)
# Out:
#        Grade Sub Grade             Employ Title Home Ownership  \
# 187648     B        B2  The Walt Disney Company       MORTGAGE
# 430862     B        B5            Fleet Manager           RENT
#
#        Verification Status Issue Date Loan Status Payment Plan  \
# 187648            Verified        Nov  Fully Paid            n
# 430862     Source Verified        Mar     Current            n
#
#                                                       url Description  \
# 187648  https://www.lendingclub.com/browse/loanDetail....         NaN
# 430862  https://www.lendingclub.com/browse/loanDetail....         NaN
#
#             Purpose                    Title Zip Code Addres States  \
# 187648      wedding             Wedding Loan    328xx            FL
# 430862  credit_card  Credit card refinancing    953xx            CA
#
#        Initial status Last Payment Date Next Payment Date Credit Pull Date  \
# 187648              w               Nov               NaN              Jan
# 430862              f               Jan            Feb-16              Jan
#
#        Application Type
# 187648       INDIVIDUAL
# 430862       INDIVIDUAL

# %%
Num_df.sample(2)
# Out:
#               id    Member  Loan Amount  Funded Amount  Amount Investors  \
# 339002  22472107  24794983        11200          11200           11200.0
# 258566  34452459  37115753        18000          18000           18000.0
#
#         Tenor   Rate  Installment  Employ Length  Annual Income    dti  \
# 339002     60  14.49       263.46              9        75000.0  17.60
# 258566     60  17.14       448.71             10        54600.0   8.97
#
#         Delinq 2 Years  Earlist Credit Line  Inquiries Last 6Months  \
# 339002             0.0                    6                     0.0
# 258566             0.0                    1                     1.0
#
#         Months Last Delinq  Months Last Record  Open Accord Credits  \
# 339002                 NaN                 NaN                  8.0
# 258566                 NaN                 NaN                  8.0
#
#         Public Record  Revolving Balance  Revolving Ultilization Rate  \
# 339002            0.0               8325                         74.3
# 258566            0.0              14186                         76.3
#
#         Total Accord  Outstanding Pricipal  Outstanding Pricipal Investors  \
# 339002          12.0                  0.00                            0.00
# 258566          20.0              15053.63                        15053.63
#
#         Total Payment  Total Payment Investation  Total Received Principal  \
# 339002       12854.57                   12854.57                  11200.00
# 258566        6132.73                    6132.73                   2946.37
#
#         Total Interest Received  Total Received Late  Recoveries  \
# 339002                  1654.57                  0.0         0.0
# 258566                  3186.36                  0.0         0.0
#
#         Collection Recovery Fee  Last Payment Amount  Collections 12 Months  \
# 339002                      0.0              9693.05                    0.0
# 258566                      0.0               448.71                    0.0
#
#         Months Since Recent 90 Day  Police Code  Accord Now Delinq  \
# 339002                         NaN            1                0.0
# 258566                         NaN            1                0.0
#
#         Total Collection Amount  Total Current Balance  \
# 339002                      0.0               131802.0
# 258566                      0.0               168795.0
#
#         Total Revolving High Limit
# 339002                     11200.0
# 258566                     18600.0

# %%
data['Addres States'].unique()
# Out:
# array(['AZ', 'GA', 'IL', 'CA', 'OR', 'NC', 'TX', 'VA', 'MO', 'CT', 'UT',
#        'FL', 'NY', 'PA', 'MN', 'NJ', 'KY', 'OH', 'SC', 'RI', 'LA', 'MA',
#        'WA', 'WI', 'AL', 'CO', 'KS', 'NV', 'AK', 'MD', 'WV', 'VT', 'MI',
#        'DC', 'SD', 'NH', 'AR', 'NM', 'MT', 'HI', 'WY', 'OK', 'DE', 'MS',
#        'TN', 'IA', 'NE', 'ID', 'IN', 'ME'], dtype=object)

# %%
# Pendapatan tahunan berdasarkan negara
agg_country = data.groupby('Addres States').agg({'Annual Income':'mean'}).reset_index()
agg_country

# Membuat Visualisasi
plt.figure(figsize=(25, 10))
plt.plot(agg_country['Addres States'], agg_country['Annual Income'], marker='o', linestyle='-', color='b')

for i, row in agg_country.iterrows():
    plt.annotate(f'{row["Annual Income"]:.2f}', (row['Addres States'], row['Annual Income'] + 1000), ha='center')

plt.title('Rata-rata Annual Income per Negara Bagian')
plt.xlabel('Negara Bagian (Addres States)')
plt.ylabel('Rata-rata Annual Income')
plt.grid(True)
plt.show()

# %% [markdown]
# Berdasarkan analisa terdapat 3 negara yang memiliki jumlah pendapatan tahunan rendah yaitu :IA, ID dan ME

# %%
num_df=['Loan Amount',	'Funded Amount',	'Amount Investors',	'Rate',	'Installment',	'Employ Length',	'Annual Income',	'dti',	'Delinq 2 Years',	'Earlist Credit Line',	'Inquiries Last 6Months',	'Months Last Delinq',	'Months Last Record',	'Open Accord Credits',	'Public Record',	'Revolving Balance',	'Revolving Ultilization Rate',	'Total Accord',	'Outstanding Pricipal',	'Outstanding Pricipal Investors',	'Total Payment',	'Total Payment Investation',	'Total Received Principal',	'Total Interest Received',	'Total Received Late',	'Recoveries',	'Collection Recovery Fee',	'Last Payment Amount',	'Collections 12 Months',	'Months Since Recent 90 Day',	'Police Code',	'Accord Now Delinq',	'Total Collection Amount',	'Total Current Balance',	'Total Revolving High Limit']
plt.figure(figsize=(15,55))
for i in range (0, len(num_df)):
  plt. subplot(len(num_df),4, i+1)
  sns.boxplot(y=data[num_df[i]], color='green', orient='v')
  plt.tight_layout()
# Out:
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# f:\Anaconda\envs\tutorial_notebook\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\USER\AppData\Local\Temp\ipykernel_17144\616566179.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# Hampir semua feature numerik memiliki outlier.

# %%
Cat_df=['Grade',	'Sub Grade',	'Home Ownership',	'Verification Status',	'Loan Status',	'Payment Plan',	'Purpose',	'Initial status']

for i in range(len(Cat_df)):
  plt.figure(figsize=(7,5))
  sns.countplot(x=data[Cat_df[i]], data=data, color='green')
  plt.xticks(rotation=90)

# %%
#data = data.drop (columns=['id','Member'],axis=1)
c= data.corr()
k = 30
cols = c.nlargest(k, c.columns).index
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.10)
plt.figure(figsize=(25,15))
sns.heatmap(cm, cbar=True,annot=True, cmap='BrBG', fmt='.1f',annot_kws={'size':10}, square=True, yticklabels=cols.values, xticklabels=cols.values )
plt.show()
# Out:
# <ipython-input-61-3b224becf01a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= data.corr()

# %%
cr = data.corr()
plt.figure(figsize=(25,20))
sns.heatmap(c, cbar=True,annot=True, cmap='BrBG',fmt='.1f')
# Out:
# <ipython-input-65-fa979a763e94>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cr = data.corr()
# <Axes: >

# %%
data.to_csv('data.csv',index=False)
